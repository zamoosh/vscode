# %%
import pandas as pd

xls: pd.DataFrame = pd.ExcelFile("/home/zamoosh/Downloads/khotbeh.xlsx")

# %%
df: pd.DataFrame = xls.parse("31")

# %%
df.describe()
# Out:
#        \nو من كلام له (عليه السلام) لما أنفذ عبد الله بن عباس إلى الزبير يستفيئه إلى طاعته قبل حرب الجمل :  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        ( در آغاز جنگ جمل در سال 36.هجرى، ابن عباس  را براى پند دادن به سوى زبير فرستاد و فرمود: )  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# ...
