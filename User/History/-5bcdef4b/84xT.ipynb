# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from pandas.core.indexes.base import Index
from pandas.core.series import Series
from typing import Any

# %%
xls: pd.ExcelFile = pd.ExcelFile("./mafatih.xlsx")

# %%
df: pd.DataFrame = xls.parse("مفاتیح")

# %%
df
# Out:
#                     عنوان ف1                        عنوان ف2  \
# 0      باب اول: در ادعیه است  فصل اول: تعقیبات مشترکه نمازها
# 1      باب اول: در ادعیه است  فصل اول: تعقیبات مشترکه نمازها
# 2      باب اول: در ادعیه است  فصل اول: تعقیبات مشترکه نمازها
# 3      باب اول: در ادعیه است  فصل اول: تعقیبات مشترکه نمازها
# 4      باب اول: در ادعیه است  فصل اول: تعقیبات مشترکه نمازها
# ...                      ...                             ...
# 13478                    NaN                             NaN
# 13479                    NaN                             NaN
# 13480                    NaN                             NaN
# 13481                    NaN                             NaN
# 13482                    NaN                             NaN
#
#                                               عنوان ف3 عنوان ف4  \
# 0                               تکبیرات بعد از هر نماز      NaN
# 1      دعای لَا إِلٰهَ إِلّا اللّٰهُ إِلٰهاً وَاحِداً       NaN
# 2      دعای لَا إِلٰهَ إِلّا اللّٰهُ إِلٰهاً وَاحِداً       NaN
# 3      دعای لَا إِلٰهَ إِلّا اللّٰهُ إِلٰهاً وَاحِداً       NaN
# 4      دعای لَا إِلٰهَ إِلّا اللّٰهُ إِلٰهاً وَاحِداً       NaN
# ...                                                ...      ...
# 13478                                              NaN      NaN
# 13479                                              NaN      NaN
# 13480                                              NaN      NaN
# 13481                                              NaN      NaN
# 13482                                              NaN      NaN
#
#                                                 عنوان ع1  \
# 0      الباب الاوّل: في تعقيب الصلوات ودعوات أيّام ال...
# 1      الباب الاوّل: في تعقيب الصلوات ودعوات أيّام ال...
# 2      الباب الاوّل: في تعقيب الصلوات ودعوات أيّام ال...
# 3      الباب الاوّل: في تعقيب الصلوات ودعوات أيّام ال...
# 4      الباب الاوّل: في تعقيب الصلوات ودعوات أيّام ال...
# ...                                                  ...
# 13478                                                NaN
# 13479                                                NaN
# 13480                                                NaN
# 13481                                                NaN
# 13482                                                NaN
#
#                                 عنوان ع2  \
# 0      الفصل الأول: في التعقيبات العامّة
# 1      الفصل الأول: في التعقيبات العامّة
# 2      الفصل الأول: في التعقيبات العامّة
# 3      الفصل الأول: في التعقيبات العامّة
# 4      الفصل الأول: في التعقيبات العامّة
# ...                                  ...
# 13478                                NaN
# 13479                                NaN
# 13480                                NaN
# 13481                                NaN
# 13482                                NaN
#
#                                               عنوان ع3 عنوان ع4  نوع  \
# 0                                                  NaN      NaN  1.0
# 1      دُعاء لَا إِلٰهَ إِلّا اللّٰهُ إِلٰهاً وَاحِداً      NaN  2.0
# 2      دُعاء لَا إِلٰهَ إِلّا اللّٰهُ إِلٰهاً وَاحِداً      NaN  2.0
# 3      دُعاء لَا إِلٰهَ إِلّا اللّٰهُ إِلٰهاً وَاحِداً      NaN  2.0
# 4      دُعاء لَا إِلٰهَ إِلّا اللّٰهُ إِلٰهاً وَاحِداً      NaN  2.0
# ...                                                ...      ...  ...
# 13478                                              NaN      NaN  2.0
# 13479                                              NaN      NaN  2.0
# 13480                                              NaN      NaN  2.0
# 13481                                              NaN      NaN  2.0
# 13482                                              NaN      NaN  2.0
#
#                                                      متن  \
# 0      فإذا سَلّمت وفرغت من الصلاة فَقُل : الله أَكبر...
# 1      لَا إِلٰهَ إِلّا اللّٰهُ إِلٰهاً وَاحِداً وَنَ...
# 2      مُخْلِصِينَ لَهُ الدِّينَ وَلَوْ كَرِهَ الْمُش...
# 3      اإِلٰهَ إِلّا اللّٰهُ وَحْدَهُ وَحْدَهُ وَحْدَ...
# 4      وَهَزَمَ الْأَحْزَابَ وَحْدَهُ، فَلَهُ الْمُلْ...
# ...                                                  ...
# 13478                                                NaN
# 13479                                                NaN
# 13480                                                NaN
# 13481                                                NaN
# 13482                                                NaN
#
#                                                  ترجمه 1 توضیحات
# 0      از کتاب «مصباح» شیخ طوسی و غیر آن روایت شده: ه...     NaN
# 1      معبودی جز خدا نیست، معبودی یگانه و ما تسلیم او...     NaN
# 2      درحالی‌که طاعت خود را برای او خالص می‌کنیم هرچ...     NaN
# 3      معبودی غیر از خدا نیست، یگانه و یگانه و یگانه ...     NaN
# 4      و به‌تنهایی لشکریان (کفر و شرک) را درهم شکست؛ ...     NaN
# ...                                                  ...     ...
# 13478                                                NaN     NaN
# 13479                                                NaN     NaN
# 13480                                                NaN     NaN
# 13481                                                NaN     NaN
# 13482                                                NaN     NaN
#
# [13483 rows x 12 columns]
